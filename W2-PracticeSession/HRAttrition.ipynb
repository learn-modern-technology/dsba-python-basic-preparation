# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;">Problem Statement
#
# Employee Attrition has always been a crucial concern for a company. Attrition means a loss to the company in terms of cost invested in training an employee. There are a few companies which were forced to close due to high level of attrition. To minimize attrition several companies tries to analyze and understand several factors which migh lead to an employee to leave the company.
# The IBM HR Attrition Case Study is a dataset which aims to identify important factors that might be influential in determining an employee who might leave the company. You are hired by the company and your objective is to undestand the data and to identify the patterns in the data which will help HR team to take decisive actions to reduce the attrition rate.
#
# There are two given dataset, Company_Data.csv contains information of an employee related to the company and Personal_Data cotains personal information of an employee.

# %% [markdown]
# ## Data Dictionary
#
# 1. EmpId-              Employee ID
# 2. AGE-                Employee Age
# 3. EducationField-     Field of Education
# 4. Gender        -     Employee Gender
# 5. MaritalStatus -     Employee Marital Status
# 6. DistanceFromHome-   Distance from home to work (in miles)
# 7. BusinessTravel-     Frequency of business travel
# 8. Department-         Department of the employee
# 9. HourlyRate-         Hourly rate of an employee
# 10. JobLevel-          Job Level of the employee. Higher job level means senior post
# 11. JobRole-           Job Role of an employee
# 12. JobSatisfaction-   Job Satisfaction level of  an employee
# 13. MonthlyRate-       Montly rate of an employee
# 14. NumCompaniesWorked-How many companies has the employee worked before
# 15. OverTime-          Does the employee gets overtime
# 16. PercentSalaryHike- Average percentage take for the employee
# 17. TotalWorkingYears- Total Years of Experience of an employee
# 18. WorkLifeBalance-   Work life balance of an employee (4 means highly satisfied)
# 19. YearsAtCompany-    Years employee have worked in current company
# 20. YearsInCurrentRole-Years employee have worked in current role
# 21. TotalWorkingYears- Total Years of Experience of an employee
# 22. YearsSinceLastPromotion-   Number of years since last promotion
# 23. YearsWithCurrManager- Number of years with current manager
# 24. Attrition-         Employee has left the company or not

# %% [markdown]
# ### Change your Working Directory

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Sudhanshu\\gitrepository\\dsba-python-basic-preparation\\W2-PracticeSession'

# %% [markdown]
# ### Q1. Import all the necessary libraries (Numpy and Pandas)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Q2. Import both csv files (and name Company_Data as "company" and Personal_Data as "personal" )

# %% [markdown]
# Load the Data file into Python DataFrame using pandas read_csv method

# %%
df_company=pd.read_csv('HRAttritionCompanyData.csv')
df_personal=pd.read_csv('HRAttritionPersonalData.csv')

# %%
df_company.head()
# Out:
#      EmpID     BusinessTravel              Department  HourlyRate  JobLevel  \
# 0  2102210      Travel_Rarely                   Sales          94       2.0
# 1  2102211  Travel_Frequently  Research & Development          61       2.0
# 2  2102212      Travel_Rarely  Research & Development          92       1.0
# 3  2102213  Travel_Frequently  Research & Development          56       1.0
# 4  2102214      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  PercentSalaryHike  TotalWorkingYears  WorkLifeBalance  \
# 0      Yes                 11                  8              1.0
# 1       No                 23                 10              3.0
# 2      Yes                 15                  7              3.0
# 3      Yes                 11                  8              3.0
# 4       No                 12                  6              3.0
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager Attrition
# 0                     5       Yes
# 1                     7        No
# 2                     0       Yes
# 3                     0        No
# 4                     2        No

# %%
df_personal.head()
# Out:
#      EmpID  Age EducationField  Gender MaritalStatus  DistanceFromHome
# 0  2102210   41  Life Sciences  Female        Single                 1
# 1  2102211   49  Life Sciences    Male       Married                 8
# 2  2102212   37          Other    Male        Single                 2
# 3  2102213   33  Life Sciences  Female       Married                 3
# 4  2102214   27        Medical    Male       Married                 2

# %% [markdown]
# ### Q3.  View Top 10 rows of both the datasets

# %% [markdown]
# Hint:Head function is used to view the top records. The number of records to be viewed, needs to be  given in the parenthesis. Default value is 5.

# %%
df_company.head(10)
# Out:
#      EmpID     BusinessTravel              Department  HourlyRate  JobLevel  \
# 0  2102210      Travel_Rarely                   Sales          94       2.0
# 1  2102211  Travel_Frequently  Research & Development          61       2.0
# 2  2102212      Travel_Rarely  Research & Development          92       1.0
# 3  2102213  Travel_Frequently  Research & Development          56       1.0
# 4  2102214      Travel_Rarely  Research & Development          40       1.0
# 5  2102215  Travel_Frequently  Research & Development          79       1.0
# 6  2102216      Travel_Rarely  Research & Development          81       1.0
# 7  2102217      Travel_Rarely  Research & Development          67       1.0
# 8  2102218  Travel_Frequently  Research & Development          44       3.0
# 9  2102219      Travel_Rarely  Research & Development          94       2.0
#
#                      JobRole  JobSatisfaction  MonthlyRate  \
# 0            Sales Executive                4        19479
# 1         Research Scientist                2        24907
# 2      Laboratory Technician                3         2396
# 3         Research Scientist                3        23159
# 4      Laboratory Technician                2        16632
# 5      Laboratory Technician                4        11864
# 6      Laboratory Technician                1         9964
# 7      Laboratory Technician                3        13335
# 8     Manufacturing Director                3         8787
# 9  Healthcare Representative                3        16577
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  TotalWorkingYears  \
# 0                   8      Yes                 11                  8
# 1                   1       No                 23                 10
# 2                   6      Yes                 15                  7
# 3                   1      Yes                 11                  8
# 4                   9       No                 12                  6
# 5                   0       No                 13                  8
# 6                   4      Yes                 20                 12
# 7                   1       No                 22                  1
# 8                   0       No                 21                 10
# 9                   6       No                 13                 17
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0              1.0               6                   4
# 1              3.0              10                   7
# 2              3.0               0                   0
# 3              3.0               8                   7
# 4              3.0               2                   2
# 5              2.0               7                   7
# 6              2.0               1                   0
# 7              3.0               1                   0
# 8              3.0               9                   7
# 9              2.0               7                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager Attrition
# 0                        0                     5       Yes
# 1                        1                     7        No
# 2                        0                     0       Yes
# 3                        3                     0        No
# 4                        2                     2        No
# 5                        3                     6        No
# 6                        0                     0        No
# 7                        0                     0        No
# 8                        1                     8        No
# 9                        7                     7        No

# %%
df_personal.head(10)
# Out:
#      EmpID  Age EducationField  Gender MaritalStatus  DistanceFromHome
# 0  2102210   41  Life Sciences  Female        Single                 1
# 1  2102211   49  Life Sciences    Male       Married                 8
# 2  2102212   37          Other    Male        Single                 2
# 3  2102213   33  Life Sciences  Female       Married                 3
# 4  2102214   27        Medical    Male       Married                 2
# 5  2102215   32  Life Sciences    Male        Single                 2
# 6  2102216   59        Medical  Female       Married                 3
# 7  2102217   30  Life Sciences    Male      Divorced                24
# 8  2102218   38  Life Sciences    Male        Single                23
# 9  2102219   36        Medical    Male       Married                27

# %% [markdown]
# ### Q4. Merge both datasets and name the merged dataset as df
#
# Hint:Merge the datasets using pd.merge() command- Use how="outer" and on="EmpID"

# %%
df_merged = df_company.merge(df_personal, how="outer", on = 'EmpID')

# %%
df_company.shape
# Out:
# (1470, 18)

# %%
df_personal.shape
# Out:
# (1470, 6)

# %%
df_merged.shape
# Out:
# (1470, 23)

# %%
df_merged.head()
# Out:
#      EmpID     BusinessTravel              Department  HourlyRate  JobLevel  \
# 0  2102210      Travel_Rarely                   Sales          94       2.0
# 1  2102211  Travel_Frequently  Research & Development          61       2.0
# 2  2102212      Travel_Rarely  Research & Development          92       1.0
# 3  2102213  Travel_Frequently  Research & Development          56       1.0
# 4  2102214      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  ...  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0      Yes  ...               6                   4                        0
# 1       No  ...              10                   7                        1
# 2      Yes  ...               0                   0                        0
# 3      Yes  ...               8                   7                        3
# 4       No  ...               2                   2                        2
#
#    YearsWithCurrManager  Attrition  Age  EducationField  Gender  \
# 0                     5        Yes   41   Life Sciences  Female
# 1                     7         No   49   Life Sciences    Male
# 2                     0        Yes   37           Other    Male
# 3                     0         No   33   Life Sciences  Female
# 4                     2         No   27         Medical    Male
#
#    MaritalStatus DistanceFromHome
# 0         Single                1
# 1        Married                8
# 2         Single                2
# 3        Married                3
# 4        Married                2
#
# [5 rows x 23 columns]

# %% [markdown]
#  ### Q5. View Last 5 records of combined dataframe "df".

# %% [markdown]
# Hint:Tail function is used to view the last records. The number of records to be viewed, needs to be given in the parenthesis.Default value is 5.

# %%
df_merged.tail()
# Out:
#         EmpID     BusinessTravel              Department  HourlyRate  \
# 1465  2103675  Travel_Frequently  Research & Development          41
# 1466  2103676      Travel_Rarely  Research & Development          42
# 1467  2103677      Travel_Rarely  Research & Development          87
# 1468  2103678  Travel_Frequently                   Sales          63
# 1469  2103679      Travel_Rarely  Research & Development          82
#
#       JobLevel                    JobRole  JobSatisfaction  MonthlyRate  \
# 1465       2.0      Laboratory Technician                4        12290
# 1466       3.0  Healthcare Representative                1        21457
# 1467       2.0     Manufacturing Director                2         5174
# 1468       2.0            Sales Executive                2        13243
# 1469       2.0      Laboratory Technician                3        10228
#
#       NumCompaniesWorked OverTime  ...  YearsAtCompany  YearsInCurrentRole  \
# 1465                   4       No  ...               5                   2
# 1466                   4       No  ...               7                   7
# 1467                   1      Yes  ...               6                   2
# 1468                   2       No  ...               9                   6
# 1469                   2       No  ...               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition  Age  \
# 1465                        0                     3         No   36
# 1466                        1                     7         No   39
# 1467                        0                     3         No   27
# 1468                        0                     8         No   49
# 1469                        1                     2         No   34
#
#       EducationField Gender  MaritalStatus DistanceFromHome
# 1465         Medical   Male        Married               23
# 1466         Medical   Male        Married                6
# 1467   Life Sciences   Male        Married                4
# 1468         Medical   Male        Married                2
# 1469         Medical   Male        Married                8
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Q6. Display the shape/dimensions of dataset.

# %% [markdown]
# Displaying the shape of the Data Frame in which first value gives number of Rows and second value gives number of columns.
#
# Hint: Use "shape" function

# %%
df_company.shape
# Out:
# (1470, 18)

# %%
df_personal.shape
# Out:
# (1470, 6)

# %%
df_merged.shape
# Out:
# (1470, 23)

# %% [markdown]
# ### Q7. Check for missing values. Display number of null values per column.

# %% [markdown]
# Hint: use isnull() function

# %%
df_merged.isnull().sum()
# Out:
# EmpID                      0
# BusinessTravel             0
# Department                 0
# HourlyRate                 0
# JobLevel                   6
# JobRole                    0
# JobSatisfaction            0
# MonthlyRate                0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# TotalWorkingYears          0
# WorkLifeBalance            4
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Attrition                  0
# Age                        0
# EducationField             0
# Gender                     0
# MaritalStatus              0
# DistanceFromHome           0
# dtype: int64

# %% [markdown]
# There are missing values present in the "Joblevel" and "WorklifeBalance" variables of the dataset.

# %% [markdown]
# ### Q8.  Drop null values from "df" and check if there are any missing value left after dropping null values

# %%
df_merged.dropna(inplace=True)

# %%
df_merged.isnull().sum()
# Out:
# EmpID                      0
# BusinessTravel             0
# Department                 0
# HourlyRate                 0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MonthlyRate                0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Attrition                  0
# Age                        0
# EducationField             0
# Gender                     0
# MaritalStatus              0
# DistanceFromHome           0
# dtype: int64

# %% [markdown]
# ### Q9. Check the datatype, number of non negative values and name of each variable in the dataset.
#
# Hint : Use info() function

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmpID                    1460 non-null   int64
#  1   BusinessTravel           1460 non-null   object
#  2   Department               1460 non-null   object
#  3   HourlyRate               1460 non-null   int64
#  4   JobLevel                 1460 non-null   float64
#  5   JobRole                  1460 non-null   object
#  6   JobSatisfaction          1460 non-null   int64
#  7   MonthlyRate              1460 non-null   int64
#  8   NumCompaniesWorked       1460 non-null   int64
#  9   OverTime                 1460 non-null   object
#  10  PercentSalaryHike        1460 non-null   int64
#  11  TotalWorkingYears        1460 non-null   int64
#  12  WorkLifeBalance          1460 non-null   float64
#  13  YearsAtCompany           1460 non-null   int64
#  14  YearsInCurrentRole       1460 non-null   int64
#  15  YearsSinceLastPromotion  1460 non-null   int64
#  16  YearsWithCurrManager     1460 non-null   int64
#  17  Attrition                1460 non-null   object
#  18  Age                      1460 non-null   int64
#  19  EducationField           1460 non-null   object
#  20  Gender                   1460 non-null   object
#  21  MaritalStatus            1460 non-null   object
#  22  DistanceFromHome         1460 non-null   int64
# dtypes: float64(2), int64(13), object(8)
# memory usage: 273.8+ KB

# %% [markdown]
# ### Q10. Check the summary of the dataset
# Hint: To see the summary of a dataframe we will use describe function.

# %%
df_merged.describe(include='all').T
# Out:
#                           count unique                     top  freq  \
# EmpID                    1460.0    NaN                     NaN   NaN
# BusinessTravel             1460      3           Travel_Rarely  1036
# Department                 1460      3  Research & Development   952
# HourlyRate               1460.0    NaN                     NaN   NaN
# JobLevel                 1460.0    NaN                     NaN   NaN
# JobRole                    1460      9         Sales Executive   325
# JobSatisfaction          1460.0    NaN                     NaN   NaN
# MonthlyRate              1460.0    NaN                     NaN   NaN
# NumCompaniesWorked       1460.0    NaN                     NaN   NaN
# OverTime                   1460      2                      No  1048
# PercentSalaryHike        1460.0    NaN                     NaN   NaN
# TotalWorkingYears        1460.0    NaN                     NaN   NaN
# WorkLifeBalance          1460.0    NaN                     NaN   NaN
# YearsAtCompany           1460.0    NaN                     NaN   NaN
# YearsInCurrentRole       1460.0    NaN                     NaN   NaN
# YearsSinceLastPromotion  1460.0    NaN                     NaN   NaN
# YearsWithCurrManager     1460.0    NaN                     NaN   NaN
# Attrition                  1460      2                      No  1225
# Age                      1460.0    NaN                     NaN   NaN
# EducationField             1460      6           Life Sciences   600
# Gender                     1460      2                    Male   875
# MaritalStatus              1460      3                 Married   671
# DistanceFromHome         1460.0    NaN                     NaN   NaN
#
#                                    mean          std        min         25%  \
# EmpID                    2102949.219178   422.080035  2102210.0  2102584.75
# BusinessTravel                      NaN          NaN        NaN         NaN
# Department                          NaN          NaN        NaN         NaN
# HourlyRate                    65.914384    20.316655       30.0        48.0
# JobLevel                       2.065753     1.107544        1.0         1.0
# JobRole                             NaN          NaN        NaN         NaN
# JobSatisfaction                2.729452     1.103963        1.0         2.0
# MonthlyRate                14299.465068  7123.418042     2094.0     8039.75
# NumCompaniesWorked             2.696575     2.499154        0.0         1.0
# OverTime                            NaN          NaN        NaN         NaN
# PercentSalaryHike             15.218493     3.666092       11.0        12.0
# TotalWorkingYears             11.286301     7.778828        0.0         6.0
# WorkLifeBalance                2.762329     0.707605        1.0         2.0
# YearsAtCompany                 7.028767      6.13939        0.0         3.0
# YearsInCurrentRole             4.243836     3.628309        0.0         2.0
# YearsSinceLastPromotion        2.197945     3.229596        0.0         0.0
# YearsWithCurrManager           4.133562     3.573852        0.0         2.0
# Attrition                           NaN          NaN        NaN         NaN
# Age                           36.910959     9.126498       18.0        30.0
# EducationField                      NaN          NaN        NaN         NaN
# Gender                              NaN          NaN        NaN         NaN
# MaritalStatus                       NaN          NaN        NaN         NaN
# DistanceFromHome               9.172603     8.101841        1.0         2.0
#
#                                50%         75%        max
# EmpID                    2102949.5  2103314.25  2103679.0
# BusinessTravel                 NaN         NaN        NaN
# Department                     NaN         NaN        NaN
# HourlyRate                    66.0        84.0      100.0
# JobLevel                       2.0         3.0        5.0
# JobRole                        NaN         NaN        NaN
# JobSatisfaction                3.0         4.0        4.0
# MonthlyRate                14225.5     20460.5    26999.0
# NumCompaniesWorked             2.0         4.0        9.0
# OverTime                       NaN         NaN        NaN
# PercentSalaryHike             14.0        18.0       25.0
# TotalWorkingYears             10.0        15.0       40.0
# WorkLifeBalance                3.0         3.0        4.0
# YearsAtCompany                 5.0        10.0       40.0
# YearsInCurrentRole             3.0         7.0       18.0
# YearsSinceLastPromotion        1.0         3.0       15.0
# YearsWithCurrManager           3.0         7.0       17.0
# Attrition                      NaN         NaN        NaN
# Age                           36.0        43.0       60.0
# EducationField                 NaN         NaN        NaN
# Gender                         NaN         NaN        NaN
# MaritalStatus                  NaN         NaN        NaN
# DistanceFromHome               7.0        14.0       29.0

# %% [markdown]
# ### Q11. Drop  the variable EmpID from the dataframe df.
# To drop any variable, use drop() function.

# %%
df_merged.head()
# Out:
#      EmpID     BusinessTravel              Department  HourlyRate  JobLevel  \
# 0  2102210      Travel_Rarely                   Sales          94       2.0
# 1  2102211  Travel_Frequently  Research & Development          61       2.0
# 2  2102212      Travel_Rarely  Research & Development          92       1.0
# 3  2102213  Travel_Frequently  Research & Development          56       1.0
# 4  2102214      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  ...  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0      Yes  ...               6                   4                        0
# 1       No  ...              10                   7                        1
# 2      Yes  ...               0                   0                        0
# 3      Yes  ...               8                   7                        3
# 4       No  ...               2                   2                        2
#
#    YearsWithCurrManager  Attrition  Age  EducationField  Gender  \
# 0                     5        Yes   41   Life Sciences  Female
# 1                     7         No   49   Life Sciences    Male
# 2                     0        Yes   37           Other    Male
# 3                     0         No   33   Life Sciences  Female
# 4                     2         No   27         Medical    Male
#
#    MaritalStatus DistanceFromHome
# 0         Single                1
# 1        Married                8
# 2         Single                2
# 3        Married                3
# 4        Married                2
#
# [5 rows x 23 columns]

# %%
df_merged.drop(['EmpID'],axis=1,inplace=True)

# %%
df_merged.head()
# Out:
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  PercentSalaryHike  ...  YearsAtCompany  YearsInCurrentRole  \
# 0      Yes                 11  ...               6                   4
# 1       No                 23  ...              10                   7
# 2      Yes                 15  ...               0                   0
# 3      Yes                 11  ...               8                   7
# 4       No                 12  ...               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  Age  \
# 0                        0                     5        Yes   41
# 1                        1                     7         No   49
# 2                        0                     0        Yes   37
# 3                        3                     0         No   33
# 4                        2                     2         No   27
#
#   EducationField  Gender MaritalStatus DistanceFromHome
# 0  Life Sciences  Female        Single                1
# 1  Life Sciences    Male       Married                8
# 2          Other    Male        Single                2
# 3  Life Sciences  Female       Married                3
# 4        Medical    Male       Married                2
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q12. Check how many employees left the company from the given dataset
# Hint :Use value_counts() function

# %%
df_merged['Attrition'].value_counts()
# Out:
# No     1225
# Yes     235
# Name: Attrition, dtype: int64

# %%
df_merged['Attrition'].value_counts(normalize=True)
# Out:
# No     0.839041
# Yes    0.160959
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Q13. Create a subset "df_new" from the dataset "df" which contain data of all the employees who have attrited. Also check the shape of the new dataset

# %%
df_subset = df_merged[df_merged["Attrition"]=='Yes']

# %%
df_subset.shape
# Out:
# (235, 22)

# %%
df_subset.head()
# Out:
#        BusinessTravel              Department  HourlyRate  JobLevel  \
# 0       Travel_Rarely                   Sales          94       2.0
# 2       Travel_Rarely  Research & Development          92       1.0
# 21      Travel_Rarely                   Sales          82       1.0
# 24      Travel_Rarely  Research & Development          83       1.0
# 26  Travel_Frequently  Research & Development          72       1.0
#
#                   JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0         Sales Executive                4        19479                   8
# 2   Laboratory Technician                3         2396                   6
# 21   Sales Representative                1         6986                   7
# 24     Research Scientist                1        17102                   2
# 26     Research Scientist                1         4681                   1
#
#    OverTime  PercentSalaryHike  ...  YearsAtCompany  YearsInCurrentRole  \
# 0       Yes                 11  ...               6                   4
# 2       Yes                 15  ...               0                   0
# 21       No                 23  ...               5                   3
# 24       No                 11  ...               4                   2
# 26      Yes                 22  ...              10                   2
#
#     YearsSinceLastPromotion  YearsWithCurrManager  Attrition  Age  \
# 0                         0                     5        Yes   41
# 2                         0                     0        Yes   37
# 21                        0                     3        Yes   36
# 24                        1                     3        Yes   34
# 26                        6                     7        Yes   32
#
#    EducationField  Gender MaritalStatus DistanceFromHome
# 0   Life Sciences  Female        Single                1
# 2           Other    Male        Single                2
# 21  Life Sciences    Male        Single                9
# 24        Medical    Male        Single                6
# 26  Life Sciences  Female        Single               16
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q14. Create the top 5 rows and first 5 columns in a matrix format. Use
#
# ---
#
# dataframe "df"
#
# Hint- use iloc function

# %%
df_personal.head()
# Out:
#      EmpID  Age EducationField  Gender MaritalStatus  DistanceFromHome
# 0  2102210   41  Life Sciences  Female        Single                 1
# 1  2102211   49  Life Sciences    Male       Married                 8
# 2  2102212   37          Other    Male        Single                 2
# 3  2102213   33  Life Sciences  Female       Married                 3
# 4  2102214   27        Medical    Male       Married                 2

# %%
df_matrix = df_personal.iloc[1:6,1:6]

# %%
df_matrix
# Out:
#    Age EducationField  Gender MaritalStatus  DistanceFromHome
# 1   49  Life Sciences    Male       Married                 8
# 2   37          Other    Male        Single                 2
# 3   33  Life Sciences  Female       Married                 3
# 4   27        Medical    Male       Married                 2
# 5   32  Life Sciences    Male        Single                 2

# %% [markdown]
# ### Q15.  Analyze the mean for all the variables for employees who have attrited and whose who have not.
#
# Hint: Use groupby() function

# %%
df_merged.head()
# Out:
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  PercentSalaryHike  ...  YearsAtCompany  YearsInCurrentRole  \
# 0      Yes                 11  ...               6                   4
# 1       No                 23  ...              10                   7
# 2      Yes                 15  ...               0                   0
# 3      Yes                 11  ...               8                   7
# 4       No                 12  ...               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  Age  \
# 0                        0                     5        Yes   41
# 1                        1                     7         No   49
# 2                        0                     0        Yes   37
# 3                        3                     0         No   33
# 4                        2                     2         No   27
#
#   EducationField  Gender MaritalStatus DistanceFromHome
# 0  Life Sciences  Female        Single                1
# 1  Life Sciences    Male       Married                8
# 2          Other    Male        Single                2
# 3  Life Sciences  Female       Married                3
# 4        Medical    Male       Married                2
#
# [5 rows x 22 columns]

# %%
df_merged[df_merged["Attrition"]=='Yes'].mean()  ## Wrong way to do this
# Out:
# C:\Users\Sudhanshu\AppData\Local\Temp\ipykernel_21132\120631905.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_merged[df_merged["Attrition"]=='Yes'].mean()
# HourlyRate                    65.582979
# JobLevel                       1.642553
# JobSatisfaction                2.463830
# MonthlyRate                14535.455319
# NumCompaniesWorked             2.944681
# PercentSalaryHike             15.093617
# TotalWorkingYears              8.280851
# WorkLifeBalance                2.659574
# YearsAtCompany                 5.153191
# YearsInCurrentRole             2.919149
# YearsSinceLastPromotion        1.961702
# YearsWithCurrManager           2.863830
# Age                           33.621277
# DistanceFromHome              10.582979
# dtype: float64

# %%
df_merged.groupby("Attrition").mean()
# Out:
#            HourlyRate  JobLevel  JobSatisfaction   MonthlyRate  \
# Attrition
# No          65.977959  2.146939         2.780408  14254.193469
# Yes         65.582979  1.642553         2.463830  14535.455319
#
#            NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# Attrition
# No                   2.648980          15.242449          11.862857
# Yes                  2.944681          15.093617           8.280851
#
#            WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Attrition
# No                2.782041        7.388571            4.497959
# Yes               2.659574        5.153191            2.919149
#
#            YearsSinceLastPromotion  YearsWithCurrManager        Age  \
# Attrition
# No                        2.243265              4.377143  37.542041
# Yes                       1.961702              2.863830  33.621277
#
#            DistanceFromHome
# Attrition
# No                 8.902041
# Yes               10.582979

# %% [markdown]
# ### Q16. Check the details of 5 employees who have spent maximum years in the company

# %%
df_merged.head()
# Out:
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  PercentSalaryHike  ...  YearsAtCompany  YearsInCurrentRole  \
# 0      Yes                 11  ...               6                   4
# 1       No                 23  ...              10                   7
# 2      Yes                 15  ...               0                   0
# 3      Yes                 11  ...               8                   7
# 4       No                 12  ...               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  Age  \
# 0                        0                     5        Yes   41
# 1                        1                     7         No   49
# 2                        0                     0        Yes   37
# 3                        3                     0         No   33
# 4                        2                     2         No   27
#
#   EducationField  Gender MaritalStatus DistanceFromHome
# 0  Life Sciences  Female        Single                1
# 1  Life Sciences    Male       Married                8
# 2          Other    Male        Single                2
# 3  Life Sciences  Female       Married                3
# 4        Medical    Male       Married                2
#
# [5 rows x 22 columns]

# %%
df_merged["YearsAtCompany"].sort_values(ascending=False).head()
# Out:
# 126     40
# 98      37
# 1116    36
# 270     36
# 561     34
# Name: YearsAtCompany, dtype: int64

# %%
df_merged.sort_values(by = 'YearsAtCompany',ascending = False).head()
# Out:
#      BusinessTravel              Department  HourlyRate  JobLevel  \
# 126   Travel_Rarely  Research & Development          94       3.0
# 98    Travel_Rarely                   Sales          37       4.0
# 1116  Travel_Rarely                   Sales          60       5.0
# 270   Travel_Rarely  Research & Development          81       5.0
# 561   Travel_Rarely                   Sales          31       4.0
#
#                         JobRole  JobSatisfaction  MonthlyRate  \
# 126   Healthcare Representative                4         3465
# 98              Sales Executive                3        24409
# 1116                    Manager                4        23037
# 270                     Manager                1        18938
# 561                     Manager                1        10084
#
#       NumCompaniesWorked OverTime  PercentSalaryHike  ...  YearsAtCompany  \
# 126                    1       No                 12  ...              40
# 98                     0       No                 13  ...              37
# 1116                   1       No                 21  ...              36
# 270                    0      Yes                 14  ...              36
# 561                    1       No                 11  ...              34
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 126                   10                       15                     6
# 98                    10                        1                     8
# 1116                   6                        2                    13
# 270                   10                        4                    13
# 561                    6                        1                    16
#
#       Attrition  Age EducationField  Gender MaritalStatus DistanceFromHome
# 126         Yes   58        Medical  Female       Married               23
# 98           No   58        Medical    Male        Single               10
# 1116         No   55      Marketing    Male       Married               26
# 270          No   55        Medical    Male        Single                1
# 561          No   52      Marketing    Male       Married                3
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q17.  Find out the minimum "Percentage Salary Hike" the company has offered?

# %%
df_merged['PercentSalaryHike'].min()
# Out:
# 11

# %% [markdown]
# ### Q18. What is the maximum Total Working Years of an employee?

# %%
df_merged['TotalWorkingYears'].max()
# Out:
# 40

# %% [markdown]
# ### Q19. What percentage of employees stay in the company given they have spend more than 7 years with the current manager?

# %%
df_merged['YearsWithCurrManager']> 7
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468     True
# 1469    False
# Name: YearsWithCurrManager, Length: 1460, dtype: bool

# %%
df_merged['Attrition'] =='No'
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# Name: Attrition, Length: 1460, dtype: bool

# %%
df_merged[(df_merged['YearsWithCurrManager']>7)&(df_merged['Attrition'] =='No')]
# Out:
#          BusinessTravel              Department  HourlyRate  JobLevel  \
# 8     Travel_Frequently  Research & Development          44       3.0
# 15        Travel_Rarely  Research & Development          51       3.0
# 22        Travel_Rarely  Research & Development          53       3.0
# 25        Travel_Rarely  Research & Development          58       5.0
# 28        Travel_Rarely  Research & Development          42       3.0
# ...                 ...                     ...         ...       ...
# 1443      Travel_Rarely  Research & Development          56       5.0
# 1445      Travel_Rarely  Research & Development          60       4.0
# 1447         Non-Travel                   Sales          88       2.0
# 1451      Travel_Rarely                   Sales         100       2.0
# 1468  Travel_Frequently                   Sales          63       2.0
#
#                         JobRole  JobSatisfaction  MonthlyRate  \
# 8        Manufacturing Director                3         8787
# 15       Manufacturing Director                1        10195
# 22            Research Director                2        21293
# 25                      Manager                3        10735
# 28    Healthcare Representative                4         2094
# ...                         ...              ...          ...
# 1443                    Manager                3        17312
# 1445     Manufacturing Director                2         5640
# 1447            Sales Executive                4        10436
# 1451            Sales Executive                4         5982
# 1468            Sales Executive                2        13243
#
#       NumCompaniesWorked OverTime  PercentSalaryHike  ...  YearsAtCompany  \
# 8                      0       No                 21  ...               9
# 15                     1       No                 11  ...              10
# 22                     0       No                 11  ...              12
# 25                     4       No                 11  ...              14
# 28                     3       No                 14  ...              22
# ...                  ...      ...                ...  ...             ...
# 1443                   5       No                 11  ...              22
# 1445                   0       No                 23  ...              20
# 1447                   1       No                 24  ...              15
# 1451                   1       No                 11  ...              10
# 1468                   2       No                 14  ...               9
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 8                      7                        1                     8
# 15                     9                        8                     8
# 22                     6                        2                    11
# 25                    13                        4                     8
# 28                     6                        5                    17
# ...                  ...                      ...                   ...
# 1443                   6                        4                    14
# 1445                   7                        0                    10
# 1447                  12                       11                    11
# 1451                   7                        1                     9
# 1468                   6                        0                     8
#
#       Attrition  Age EducationField  Gender MaritalStatus DistanceFromHome
# 8            No   38  Life Sciences    Male        Single               23
# 15           No   29  Life Sciences  Female      Divorced               21
# 22           No   34  Life Sciences  Female        Single                7
# 25           No   53          Other  Female      Divorced                5
# 28           No   44        Medical  Female       Married                7
# ...         ...  ...            ...     ...           ...              ...
# 1443         No   42  Life Sciences    Male       Married                2
# 1445         No   41  Life Sciences  Female       Married               28
# 1447         No   36      Marketing    Male      Divorced               15
# 1451         No   38  Life Sciences  Female       Married               10
# 1468         No   49        Medical    Male       Married                2
#
# [248 rows x 22 columns]

# %%
df_merged[df_merged['YearsWithCurrManager']> 7]['Attrition'].value_counts(normalize = True)
# Out:
# No     0.918519
# Yes    0.081481
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Q20.  What percentage of employees lives >10 miles from the company?

# %%
df_merged[df_merged['DistanceFromHome']>10]['DistanceFromHome']
# Out:
# 7       24
# 8       23
# 9       27
# 10      16
# 15      21
#         ..
# 1459    13
# 1460    28
# 1461    28
# 1462    24
# 1465    23
# Name: DistanceFromHome, Length: 439, dtype: int64

# %%
df_merged[df_merged['DistanceFromHome']>10]['DistanceFromHome'].count()/df_merged.shape[0] * 100
# Out:
# 30.068493150684933

# %% [markdown]
# ### Q21. Create a copy of the dataset , remove the "Attrition" variable from the new dataset and check the shape of the dataset

# %%
df_merged_new=df_merged.copy()

# %%
df_merged_new.shape
# Out:
# (1460, 22)

# %%
df_merged_new.drop(['Attrition'],axis=1,inplace=True)

# %%
df_merged_new.head()
# Out:
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  PercentSalaryHike  ...  WorkLifeBalance  YearsAtCompany  \
# 0      Yes                 11  ...              1.0               6
# 1       No                 23  ...              3.0              10
# 2      Yes                 15  ...              3.0               0
# 3      Yes                 11  ...              3.0               8
# 4       No                 12  ...              3.0               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  Age  \
# 0                   4                        0                     5   41
# 1                   7                        1                     7   49
# 2                   0                        0                     0   37
# 3                   7                        3                     0   33
# 4                   2                        2                     2   27
#
#    EducationField  Gender MaritalStatus DistanceFromHome
# 0   Life Sciences  Female        Single                1
# 1   Life Sciences    Male       Married                8
# 2           Other    Male        Single                2
# 3   Life Sciences  Female       Married                3
# 4         Medical    Male       Married                2
#
# [5 rows x 21 columns]

# %%
df_merged_new.shape
# Out:
# (1460, 21)

# %% [markdown]
# # END
